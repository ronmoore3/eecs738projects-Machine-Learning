# %% [markdown]
# ### Create Q-learning table, reward table, and state transition table needed for reinforcement learning

# %% [markdown]
# ### Generator for transition table

# %%
import numpy as np
from math import sqrt

def transition_table_generator(states):
    
    transition_table = np.zeros((states,5))
    
    m = len(transition_table)
    n = sqrt(m)
    
    for i in range(m):
        
        for j in range(5):
            
            # check if top row, then 'up' action invalid
            if i < n:
                transition_table[i][0] = -1
            else:
                transition_table[i][0] = i - n
                
            # check if bottom row, then 'down' action invalid
            if i >= n * (n - 1):
                transition_table[i][1] = -1
            else:
                transition_table[i][1] = i + n
                
            # check if leftmost column, then 'left' action invalid
            if i % n == 0:
                transition_table[i][2] = -1
            else:
                transition_table[i][2] = i - 1
            
            # check if rightmost column, then 'right' action invalid
            if i % n == n - 1:
                transition_table[i][3] = -1
            else:
                transition_table[i][3] = i + 1
            
            # 'no move' action
            transition_table[i][4] = i
    
    transition_table = transition_table.astype(int)

    return transition_table

# %% [markdown]
# ### Generator for reward table

# %%
def reward_table_generator(board, transition_table):
    
    reward_table = np.zeros((len(transition_table), len(transition_table[0])))
    
    for i in range(len(transition_table)):
        
        for j in range(len(transition_table[0])):
            
            state = transition_table[i][j]
            
            # if no move, then reward is - 1
            if state == i:
                reward_table[i][j] = -1
            
            # if snake, quicksand, or pit, add -10 reward
            n = int(sqrt(len(transition_table)))
            row = int(state / n)
            column = int(state % n)
            if board[row][column] == 'S' or board[row][column] == 'Q' or board[row][column] == 'P':
                reward_table[i][j] = -10
            
            # if treasure, add 10
            elif board[row][column] == 'T':
                reward_table[i][j] = 10

    return reward_table

# %% [markdown]
# ### Create environment for reinforcement learning agent

# %%
def environment(board, states):
    env = dict()
    env['board'] = board
    env['transition table'] = transition_table_generator(states)
    env['reward table'] = reward_table_generator(board, env['transition table'])
    return env

# %% [markdown]
# ### Create module to display agent and environment

# %%
def draw_board(board):
    n = len(board)
    for i in range(n):
        for j in range(n):
            print(board[i][j], end=' ')
        print('\n')

# %% [markdown]
# ### Create learning module for agents

# %%
import random

def agent_learning(agent, environment, sessions):
    
    # let agent learn best actions for environment
    alpha = agent['alpha']
    gamma = agent['gamma']
    q_table = agent['q table'].copy()
    board = environment['board']
    
    # find start state and goal state
    start_state = 0
    goal_state = 0
    
    n = len(environment['board'])
    for row in environment['board']:
        for position in row:
            if position == 'A':
                start_state = environment['board'].index(row) + n * row.index(position)
            elif position == 'T':
                goal_state = environment['board'].index(row) + n * row.index(position)
    
    rewards = environment['reward table']
    transition_table = environment['transition table'].tolist()
    
    # possible actions for each state
    actions = []

    for i in transition_table:
        action = []
        for j in i:
            if j != -1:
                action.append(i.index(j))
        actions.append(action)
    
    actions = np.array(actions)
    
    
    # train agent for arbirtray number of epochs
    for i in range(sessions):
        print('Begin session %d' % (i + 1))
        steps = 0
        current_state = start_state
        
        print("Board after %d steps" % steps)
        print("-----------------------------------------------------------")
        draw_board(board)
        
        while current_state != goal_state:
            steps += 1
            # select random action for agent
            action = random.choice(actions[current_state])
            next_state = transition_table[current_state][action]
            future_rewards = []
        
            # update agent's q table
            for action in actions[next_state]:
                future_rewards.append(q_table[next_state, action])
            
            # reward function
            q_old = q_table[current_state][action]
            
            q_new = (1 - alpha) *  q_old + alpha * (rewards[current_state][action] + gamma * max(future_rewards))
            
            

            q_table[current_state][action] = q_new
            
            # update and display board
            orow = int(current_state / n)
            ocolumn = int(current_state % n)
            nrow = int(next_state / n)
            ncolumn = int(next_state % n)
            
            if board[orow][ocolumn] == 'A':
                board[orow][ocolumn] = '-'
            else:
                board[orow][ocolumn] = board[orow][ocolumn].replace('A', '')
            
            if board[nrow][ncolumn] == '-':
                 board[nrow][ncolumn] = 'A'
            else:
                board[nrow][ncolumn] += 'A'
            
            print("Board after %d steps" % steps)
            print("--------------------------------------")
            draw_board(board)           
            
            current_state = next_state
            print('Current state is now: %d' % current_state)
        
            # check if goal state reached, finish learning and reset board
            if current_state == goal_state:
                print("Goal reached after %d steps" % steps)
                board[int(start_state / n)][int(start_state % n)] = 'A'
                board[int(goal_state / n)][int(goal_state % n)] = 'T'

    
    agent['q table'] = q_table
    return agent

# %% [markdown]
# ### Create agent to learn environment

# %%
def rl_agent(environment, alpha, gamma, sessions):
    
    agent = dict()
    
    agent['alpha'] = alpha
    agent['gamma'] = gamma
    agent['q table'] = np.zeros((len(environment['transition table']), len(environment['transition table'][0])))
    # module for agent learning
    agent = agent_learning(agent, environment, sessions)
    
    return agent

# %% [markdown]
# ### Create agent to learn environment

# %%
# board displaying environment
board = [['A','S','P','-','S'],
         ['-','-','Q','S','-'],
         ['-','S','P','-','Q'],
         ['-','Q','-','T','P'],
         ['-','-','-','Q','S']]

# board = [['A','S'],
#          ['-','T']]

env = environment(board, 25)

agent_1 = rl_agent(environment=env, gamma=0.8, alpha=0.5, sessions=5)
# Out:
# Begin session 1
# Board after 0 steps
# -----------------------------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Board after 1 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 2 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 3 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 4 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 5 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 6 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 7 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 8 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 9 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 10 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 11 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 12 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 13 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 14 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 15 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 16 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 17 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 18 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 19 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 20 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 21 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 22 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 23 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 24 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 25 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 26 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 27 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 28 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 29 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 30 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 31 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 32 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 33 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 34 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 35 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 36 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 37 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 38 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 39 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 40 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 41 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 42 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 43 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 44 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 45 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 46 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 47 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 48 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 49 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 50 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 51 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 52 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 53 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 54 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 55 steps
# --------------------------------------
# - S P - SA
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 4
# Board after 56 steps
# --------------------------------------
# - S P - SA
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 4
# Board after 57 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 58 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 59 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 60 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 61 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 62 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 63 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 64 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 65 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 66 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 67 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 68 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 69 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 70 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 71 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 72 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 73 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 74 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 75 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 76 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 77 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 78 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 79 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 80 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 81 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 82 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 83 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 84 steps
# --------------------------------------
# - S P - SA
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 4
# Board after 85 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 86 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 87 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 88 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 89 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 90 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 91 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 92 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 93 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 94 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 95 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 96 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 97 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 98 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 99 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - TA P
#
# - - - Q S
#
# Current state is now: 18
# Goal reached after 99 steps
# Begin session 2
# Board after 0 steps
# -----------------------------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Board after 1 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 2 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 3 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 4 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 5 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 6 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 7 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 8 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 9 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 10 steps
# --------------------------------------
# - S P - SA
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 4
# Board after 11 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 12 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 13 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 14 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 15 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 16 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 17 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 18 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 19 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 20 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 21 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 22 steps
# --------------------------------------
# - S P A S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 3
# Board after 23 steps
# --------------------------------------
# - S P - SA
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 4
# Board after 24 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 25 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 26 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 27 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 28 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 29 steps
# --------------------------------------
# - S P - S
#
# - - Q SA -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 8
# Board after 30 steps
# --------------------------------------
# - S P - S
#
# - - Q S A
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 9
# Board after 31 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 32 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T PA
#
# - - - Q S
#
# Current state is now: 19
# Board after 33 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q SA
#
# Current state is now: 24
# Board after 34 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q SA
#
# Current state is now: 24
# Board after 35 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T PA
#
# - - - Q S
#
# Current state is now: 19
# Board after 36 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - TA P
#
# - - - Q S
#
# Current state is now: 18
# Goal reached after 36 steps
# Begin session 3
# Board after 0 steps
# -----------------------------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Board after 1 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 2 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 3 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 4 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# A - - Q S
#
# Current state is now: 20
# Board after 5 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# A - - Q S
#
# Current state is now: 20
# Board after 6 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 7 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 8 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 9 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 10 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 11 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 12 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 13 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 14 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 15 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 16 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 17 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 18 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 19 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 20 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 21 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 22 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 23 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 24 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 25 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 26 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 27 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 28 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 29 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 30 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 31 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 32 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 33 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 34 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 35 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 36 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 37 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 38 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 39 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 40 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 41 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 42 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 43 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 44 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 45 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 46 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 47 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 48 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 49 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 50 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 51 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 52 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 53 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 54 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 55 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 56 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 57 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 58 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 59 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - A - Q S
#
# Current state is now: 21
# Board after 60 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 61 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 62 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 63 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 64 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 65 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 66 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 67 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 68 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 69 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 70 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 71 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 72 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 73 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 74 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 75 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 76 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 77 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 78 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 79 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 80 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 81 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 82 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 83 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 84 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 85 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 86 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 87 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 88 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 89 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 90 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 91 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# A - - Q S
#
# Current state is now: 20
# Board after 92 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# A - - Q S
#
# Current state is now: 20
# Board after 93 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# A - - Q S
#
# Current state is now: 20
# Board after 94 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 95 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 96 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 97 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 98 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 99 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 100 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 101 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 102 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 103 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 104 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 105 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 106 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 107 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 108 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 109 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 110 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 111 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 112 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 113 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 114 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 115 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 116 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 117 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 118 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 119 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 120 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 121 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 122 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 123 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 124 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 125 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 126 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 127 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 128 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 129 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 130 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 131 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 132 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 133 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 134 steps
# --------------------------------------
# - S PA - S
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 135 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 136 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 137 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 138 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 139 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 140 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 141 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 142 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 143 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 144 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 145 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 146 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 147 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 148 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 149 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 150 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 151 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 152 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 153 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 154 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 155 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 156 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 157 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 158 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 159 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# A - - Q S
#
# Current state is now: 20
# Board after 160 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - A - Q S
#
# Current state is now: 21
# Board after 161 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - A Q S
#
# Current state is now: 22
# Board after 162 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q A T P
#
# - - - Q S
#
# Current state is now: 17
# Board after 163 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 164 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 165 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 166 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - QA
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 14
# Board after 167 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 168 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - TA P
#
# - - - Q S
#
# Current state is now: 18
# Goal reached after 168 steps
# Begin session 4
# Board after 0 steps
# -----------------------------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Board after 1 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 2 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 3 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# A S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 10
# Board after 4 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# A Q - T P
#
# - - - Q S
#
# Current state is now: 15
# Board after 5 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - QA - T P
#
# - - - Q S
#
# Current state is now: 16
# Board after 6 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - A - Q S
#
# Current state is now: 21
# Board after 7 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - A Q S
#
# Current state is now: 22
# Board after 8 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - A Q S
#
# Current state is now: 22
# Board after 9 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - QA S
#
# Current state is now: 23
# Board after 10 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - TA P
#
# - - - Q S
#
# Current state is now: 18
# Goal reached after 10 steps
# Begin session 5
# Board after 0 steps
# -----------------------------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Board after 1 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 2 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 3 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 4 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 5 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 6 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 7 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 8 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 9 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 10 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 11 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 12 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 13 steps
# --------------------------------------
# - S P - S
#
# A - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 5
# Board after 14 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 15 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 16 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 17 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 18 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 19 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 20 steps
# --------------------------------------
# - S P - S
#
# - A Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 6
# Board after 21 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 22 steps
# --------------------------------------
# A S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 0
# Board after 23 steps
# --------------------------------------
# - SA P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 1
# Board after 24 steps
# --------------------------------------
# - S PA - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 2
# Board after 25 steps
# --------------------------------------
# - S P - S
#
# - - QA S -
#
# - S P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 7
# Board after 26 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 27 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 28 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 29 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 30 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 31 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P A Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 13
# Board after 32 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 33 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 34 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - SA P - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 11
# Board after 35 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 36 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 37 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S PA - Q
#
# - Q - T P
#
# - - - Q S
#
# Current state is now: 12
# Board after 38 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q A T P
#
# - - - Q S
#
# Current state is now: 17
# Board after 39 steps
# --------------------------------------
# - S P - S
#
# - - Q S -
#
# - S P - Q
#
# - Q - TA P
#
# - - - Q S
#
# Current state is now: 18
# Goal reached after 39 steps
